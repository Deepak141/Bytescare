# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak141/Bytescare/blob/PersonCLassification/Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
from keras.preprocessing import image
import h5py
from keras.models import load_model
import matplotlib.pyplot as plt
from keras.models import model_from_json
import os

# %%
# !git clone https://github.com/Deepak141/Bytescare.git
# Out:
# Cloning into 'Bytescare'...
# remote: Enumerating objects: 68, done.
# remote: Counting objects: 100% (68/68), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 68 (delta 12), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (68/68), done.

# %%
json_file = open('/content/model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 73, 73, 512)       5120
# _________________________________________________________________
# activation_11 (Activation)   (None, 73, 73, 512)       0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 24, 24, 512)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 22, 22, 256)       1179904
# _________________________________________________________________
# activation_12 (Activation)   (None, 22, 22, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 256)         590080
# ...

# %%
model.load_weights('/content/test_weights.h5')

# %%
def check_person(img):
  img = image.img_to_array(img)
  img=img.reshape(-1,75,75,1)
  img /= 255
  res=model.predict_classes(img)
  if res[0]==0:
    print('person')
  else :
    print('not a person')

# %%
for i in (os.listdir('/content/test')):
  path=f'/content/test/{i}'
  im = image.load_img(path, target_size=(75, 75),color_mode="grayscale")
  result=check_person(im)
  cv2_imshow(cv2.imread(path))
# Out:
# not a person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8885C5F0F0>
# not a person
# <PIL.Image.Image image mode=RGB size=263x192 at 0x7F8885BC86D8>
# not a person
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7F8885C76438>
# not a person
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F8885C7EDD8>
# not a person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8885C3D828>
# person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8885BC8EB8>
# person
# <PIL.Image.Image image mode=RGB size=197x256 at 0x7F8885BC8C18>
# not a person
# <PIL.Image.Image image mode=RGB size=366x138 at 0x7F8885C7EDD8>
# person
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7F8885C03BE0>
# person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8885CCCC88>
# not a person
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F8885CCCC88>
# not a person
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7F8885B449E8>
# person
# ...

# %%
json_file = open('/content/new_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
model = model_from_json(loaded_model_json)

# %%
model.load_weights('/content/new_test_weights.h5')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_4 (Conv2D)            (None, 148, 148, 512)     14336
# _________________________________________________________________
# activation_11 (Activation)   (None, 148, 148, 512)     0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 49, 49, 512)       0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 47, 47, 256)       1179904
# _________________________________________________________________
# activation_12 (Activation)   (None, 47, 47, 256)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 256)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 13, 13, 256)       590080
# ...

# %%
def check(img):
  #img=cv2.resize(image,(100,100))
  img = image.img_to_array(img)
  img=img.reshape(-1,150,150,3)
  #img_data = img.astype('float32')
  img /= 255
  res=model.predict_classes(img)
  if res[0]==1:
    print('person')
  else :
    print('not a person')

# %%
images = image.load_img("/content/test/test6.jpg", target_size=(150, 150))
plt.imshow(images)
result=check(images)
# Out:
# not a person

# %%
for i in (os.listdir('/content/test')):
  path=f'/content/test/{i}'
  images = image.load_img(path, target_size=(150, 150))
  result=check(images)
  cv2_imshow(cv2.imread(path))
# Out:
# not a person
# <PIL.Image.Image image mode=RGB size=263x192 at 0x7F8884B16E80>
# not a person
# <PIL.Image.Image image mode=RGB size=197x256 at 0x7F8883CC4B38>
# not a person
# <PIL.Image.Image image mode=RGB size=366x138 at 0x7F8883C7C1D0>
# person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F888922BA20>
# not a person
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7F8883C7C1D0>
# person
# <PIL.Image.Image image mode=RGB size=318x159 at 0x7F8883C57D30>
# person
# <PIL.Image.Image image mode=RGB size=205x246 at 0x7F8883BBDBE0>
# person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8883C57D30>
# not a person
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F8883C57D30>
# not a person
# <PIL.Image.Image image mode=RGB size=310x163 at 0x7F8883C57D30>
# not a person
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F8883B7DFD0>
